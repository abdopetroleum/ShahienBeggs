# %% [markdown]
# # Shahien Beggs and Brill

# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import shahienetal.TraverseCurve as pt

# %% [markdown]
# Input Data

# %%
liquid_rate= 900
wc= .5
GLR = 700
gas_grav = 0.65
oil_grav = 35
wtr_grav = 1.07
diameter=1.922
angle=90.0
margin=35
thp= 0
tht=120.0
twf=180.0
depth = 15000
sample_size =100

# %%
#def Pgrad(P, T, oil_rate, wtr_rate, Gor, gas_grav, oil_grav, wtr_grav, d, angle):
p,depths=pt.pressure_traverse(liquid_rate=liquid_rate,depth=depth,tht=tht,twf=twf,
                       glr=GLR,wc=wc,gas_grav=gas_grav,oil_grav=oil_grav,
                       wtr_grav=wtr_grav,diameter=diameter,angle=angle,margin=margin,
                       thp=thp,sample_size=sample_size)

# %%
ax=pt.plot_traverse(liquid_rate=liquid_rate,ax=None,depth=depth,tht=tht,twf=twf,
                       glr=GLR,wc=wc,gas_grav=gas_grav,oil_grav=oil_grav,
                       wtr_grav=wtr_grav,diameter=diameter,angle=angle,margin=margin,
                       thp=thp,sample_size=sample_size)
plt.legend(fontsize=15)

# %% [markdown]
# # VLP Curve

# %%
def vlp(rates):
    bhps =[]
    for q in rates:
        p,depths = pt.pressure_traverse(liquid_rate=q,depth=depth,tht=tht,twf=twf,
                       glr=GLR,wc=wc,gas_grav=gas_grav,oil_grav=oil_grav,
                       wtr_grav=wtr_grav,diameter=diameter,angle=angle,margin=margin,
                       thp=thp,sample_size=sample_size)
        bhp = p[-1]
        print(bhp)
        bhps.append(bhp)
    return bhps

rates = np.linspace(100, 2300, 30)
bhps = vlp(rates)
plt.figure(figsize=(15,10))
plt.grid(b=True, which='major', color='#666666', linestyle='-')
# Show the minor grid lines with very faint and almost transparent grey lines
plt.minorticks_on()
plt.grid(b=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
plt.ylim(0,depths[-1])
plt.plot(rates, bhps, '-')
plt.xlabel('Rate STB/day')
plt.ylabel('Pressure psi')
plt.title("VLP Curve", size=20,pad=20)
plt.show()
# Out:
# 4393.175574468876
# 3331.4635861315255
# 3319.594188903165
# 3373.1432802709996
# 3453.7257516190007
# 3546.582112968911
# 3647.271987917036
# 3753.7678973528573
# 3889.1491954985777
# 4023.513643882943
# 4146.748828803021
# 4254.534606084001
# 4361.4659149802665
# 4462.368576679582
# 4567.797344920996
# 4667.190900573349
# 4771.782080830579
# 4873.754350390591
# 4977.1222627432135
# 5077.546336328434
# 5182.203237584816
# 5286.057301610553
# 5391.495150708551
# 5498.341393936073
# 5604.827617260901
# 5715.0236128929555
# 5823.680468569367
# 5935.747925716887
# 6047.866823253947
# 6163.19818850387
# C:\Users\abdo2\AppData\Local\Temp/ipykernel_17528/1299103422.py:16: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='major', color='#666666', linestyle='-')
# C:\Users\abdo2\AppData\Local\Temp/ipykernel_17528/1299103422.py:19: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='minor', color='#999999', linestyle='-', alpha=0.2)

# %% [markdown]
# # Effect of flow Rate

# %%
liquid_rates=[100,180,200,1000,2000]

# %%
ax=None
for liquid_rate in liquid_rates:
    ax=pt.plot_traverse(liquid_rate=liquid_rate,ax=ax,depth=depth,tht=tht,twf=twf,
                       glr=GLR,wc=wc,gas_grav=gas_grav,oil_grav=oil_grav,
                       wtr_grav=wtr_grav,diameter=diameter,angle=angle,margin=margin,
                       thp=thp,sample_size=sample_size)
plt.title("Traverse Curve Effect of Flow Rate", size=20,pad=20)
plt.legend(fontsize=10)
plt.show()

# %% [markdown]
# # Effect of GLR

# %%
GLRs=[1,300,500,1000,1500,2000,2500]
liquid_rate=500
depth=15000

# %%
ax=None
for GLR in GLRs:
    ax=pt.plot_traverse(liquid_rate=liquid_rate,ax=ax,depth=depth,tht=tht,twf=twf,
                       glr=GLR,wc=wc,gas_grav=gas_grav,oil_grav=oil_grav,
                       wtr_grav=wtr_grav,diameter=diameter,angle=angle,margin=margin,
                       thp=thp,sample_size=sample_size)
plt.title("Traverse Curve Effect of GLR", size=20,pad=20)
plt.legend(fontsize=10)
plt.show()
plt.show()

# %% [markdown]
# # Horizontal PipeLines

# %%
GLRs=[1,300,500,1000,1500,2000,2500]
liquid_rate=500
depth=5000
angle=0

# %%
ax=None
for GLR in GLRs:
    ax=pt.plot_traverse(liquid_rate=liquid_rate,ax=ax,depth=depth,tht=tht,twf=twf,
                       glr=GLR,wc=wc,gas_grav=gas_grav,oil_grav=oil_grav,
                       wtr_grav=wtr_grav,diameter=diameter,angle=angle,margin=margin,
                       thp=thp,sample_size=sample_size)
plt.title("Horizontal Traverse Curve Effect of GLR", size=20,pad=20)
plt.legend(fontsize=10)
plt.show()
plt.show()

# %% [markdown]
# # Depth Survey

# %%
import shahienetal.DepthSurvey as DS

# %%
true_depths=[0,3000,5000,6000,6000,10000]
measured_depths=[0,3000,6000,10500,14500,18500]

# %%
DS.plot_traverse(liquid_rate=liquid_rate,true_depths=true_depths,measured_depths=measured_depths,tht=tht,twf=twf,
                       glr=GLR,wc=wc,gas_grav=gas_grav,oil_grav=oil_grav,
                       wtr_grav=wtr_grav,diameter=diameter,margin=margin,
                       thp=thp,sample_size=sample_size)
