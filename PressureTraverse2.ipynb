# %% [markdown]
# # Shahien Beggs and Brill

# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import shahienetal.TraverseCurve as pt

# %% [markdown]
# Input Data

# %%
liquid_rate= 900
wc= .5
GLR = 700
gas_grav = 0.65
oil_grav = 35
wtr_grav = 1.07
diameter=1.922
angle=90.0
margin=35
thp= 0
tht=120.0
twf=180.0
depth = 15000
sample_size =100

# %%
#def Pgrad(P, T, oil_rate, wtr_rate, Gor, gas_grav, oil_grav, wtr_grav, d, angle):
p,depths=pt.pressure_traverse(liquid_rate=liquid_rate,depth=depth,tht=tht,twf=twf,
                       glr=GLR,wc=wc,gas_grav=gas_grav,oil_grav=oil_grav,
                       wtr_grav=wtr_grav,diameter=diameter,angle=angle,margin=margin,
                       thp=thp,sample_size=sample_size)

# %%
ax=pt.plot_traverse(liquid_rate=liquid_rate,ax=None,depth=depth,tht=tht,twf=twf,
                       glr=GLR,wc=wc,gas_grav=gas_grav,oil_grav=oil_grav,
                       wtr_grav=wtr_grav,diameter=diameter,angle=angle,margin=margin,
                       thp=thp,sample_size=sample_size)
plt.legend(fontsize=15)

# %% [markdown]
# # VLP Curve

# %%
def vlp(rates):
    bhps =[]
    for q in rates:
        p,depths = pt.pressure_traverse(liquid_rate=q,depth=depth,tht=tht,twf=twf,
                       glr=GLR,wc=wc,gas_grav=gas_grav,oil_grav=oil_grav,
                       wtr_grav=wtr_grav,diameter=diameter,angle=angle,margin=margin,
                       thp=thp,sample_size=sample_size)
        bhp = p[-1]
        print(bhp)
        bhps.append(bhp)
    return bhps

rates = np.linspace(100, 2300, 30)
bhps = vlp(rates)
plt.figure(figsize=(15,10))
plt.grid(b=True, which='major', color='#666666', linestyle='-')
# Show the minor grid lines with very faint and almost transparent grey lines
plt.minorticks_on()
plt.grid(b=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
plt.ylim(0,depths[-1])
plt.plot(rates, bhps, '-')
plt.xlabel('Rate STB/day')
plt.ylabel('Pressure psi')
plt.title("VLP Curve", size=20,pad=20)
plt.show()
# Out:
# 4393.101537761307
# 3331.456233505147
# 3319.584977910287
# 3373.1328860566027
# 3453.7131734380437
# 3546.5685240638168
# 3647.25975998382
# 3753.755665614708
# 3889.1372639370334
# 4023.504033522852
# 4146.740587019
# 4254.526222736
# 4361.457600532418
# 4462.360078770677
# 4567.788349982713
# 4667.181279879166
# 4771.772018331267
# 4873.743521429562
# 4977.110380457986
# 5077.531982645053
# 5182.191742947898
# 5286.047113418833
# 5391.486424863477
# 5498.333192645753
# 5604.8185076847285
# 5715.0147554919595
# 5823.67250185747
# 5935.74055692093
# 6047.860169244558
# 6163.192218811472
# C:\Users\abdo2\AppData\Local\Temp/ipykernel_118188/1299103422.py:16: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='major', color='#666666', linestyle='-')
# ...

# %% [markdown]
# # Effect of flow Rate

# %%
liquid_rates=[100,1000,2000]

# %%
ax=None
for liquid_rate in liquid_rates:
    ax=pt.plot_traverse(liquid_rate=liquid_rate,ax=ax,depth=depth,tht=tht,twf=twf,
                       glr=GLR,wc=wc,gas_grav=gas_grav,oil_grav=oil_grav,
                       wtr_grav=wtr_grav,diameter=diameter,angle=angle,margin=margin,
                       thp=thp,sample_size=sample_size)
plt.title("Traverse Curve Effect of Flow Rate", size=20,pad=20)
plt.legend(fontsize=10)
plt.show()

# %% [markdown]
# # Effect of GLR

# %%
GLRs=[1,300,500,1000,1500,2000,2500]
liquid_rate=500
depth=15000

# %%
ax=None
for GLR in GLRs:
    ax=pt.plot_traverse(liquid_rate=liquid_rate,ax=ax,depth=depth,tht=tht,twf=twf,
                       glr=GLR,wc=wc,gas_grav=gas_grav,oil_grav=oil_grav,
                       wtr_grav=wtr_grav,diameter=diameter,angle=angle,margin=margin,
                       thp=thp,sample_size=sample_size)
plt.title("Traverse Curve Effect of GLR", size=20,pad=20)
plt.legend(fontsize=10)
plt.show()

# %% [markdown]
# # Effect of WC

# %%
wcs=[0,.2,.4,.6,.8,.99]
liquid_rate=200
depth=15000

# %%
ax=None
for wc in wcs:
    ax=pt.plot_traverse(liquid_rate=liquid_rate,ax=ax,depth=depth,tht=tht,twf=twf,
                       glr=GLR,wc=wc,gas_grav=gas_grav,oil_grav=oil_grav,
                       wtr_grav=wtr_grav,diameter=diameter,angle=90,margin=35,
                       thp=thp,sample_size=sample_size)
plt.title("Traverse Curve Effect of WC", size=20,pad=20)
plt.legend(fontsize=10)
plt.show()

# %% [markdown]
# # Horizontal PipeLines

# %%
GLRs=[1,300,500,1000,1500,2000,2500]
liquid_rate=500
depth=5000
angle=0

# %%
ax=None
for GLR in GLRs:
    ax=pt.plot_traverse(liquid_rate=liquid_rate,ax=ax,depth=depth,tht=tht,twf=twf,
                       glr=GLR,wc=wc,gas_grav=gas_grav,oil_grav=oil_grav,
                       wtr_grav=wtr_grav,diameter=diameter,angle=angle,margin=margin,
                       thp=thp,sample_size=sample_size)
plt.title("Horizontal Traverse Curve Effect of GLR", size=20,pad=20)
plt.legend(fontsize=10)
plt.show()
plt.show()

# %% [markdown]
# # Tabered Tubing

# %%
import shahienetal.TaperedTubing as TT

# %%
measured_depths=[0,6000,14500]
diameters=[1.922,2.992]

# %%
TT.plot_traverse(liquid_rate=100,measured_depths=measured_depths,tht=150,twf=150,
                       glr=700,wc=.5,gas_grav=.65,oil_grav=35,
                       wtr_grav=1.07,diameters=diameters,margin=35,
                       thp=0,sample_size=100)
plt.legend()
# Out:
# [0, 0, 3.3220140021455293, 6.644028004291059, 9.7699308240798, 12.98354501607264, 16.28484168048486, 19.67697473776539, 23.162641980596447, 26.7442216192797, 30.42383402349232, 34.20338794176509, 38.0846153723038, 42.069098326370366, 46.15828968107277, 50.35352964834152, 54.65605894209982, 59.06702942401415, 63.58751279965743, 68.21850779016081, 72.96094609950173, 77.81569742145608, 82.78357367427837, 87.86533260952272, 93.06168091006208, 98.37327686851171, 103.80073271893801, 109.35260737096709, 115.09144795956652, 121.01780032166545, 127.13318339619596, 133.43556476705308, 139.92316116851646, 146.59775846062578, 153.46092997716954, 160.51410173857138, 167.758560026298, 175.1954586397519, 182.8258252446297, 190.66271477736726, 198.70465456051554, 206.9452020688822, 215.3883335025634, 224.02884807678737, 232.869041123994, 241.90880885143935, 251.14806826434312, 260.58669971210855, 270.22453305215987, 280.06134045131347, 290.09683280281286, 300.3306581478938, 310.7624012725271, 321.39
# ...

# %% [markdown]
# # Depth Survey

# %%
import shahienetal.DepthSurvey as DS

# %%
true_depths=[0,3000,5000,6000,6000,10000]
measured_depths=[0,3000,6000,10500,14500,18500]

# %%
DS.plot_traverse(liquid_rate=liquid_rate,true_depths=true_depths,measured_depths=measured_depths,tht=tht,twf=twf,
                       glr=GLR,wc=wc,gas_grav=gas_grav,oil_grav=oil_grav,
                       wtr_grav=wtr_grav,diameter=diameter,margin=margin,
                       thp=thp,sample_size=sample_size)
plt.legend()
